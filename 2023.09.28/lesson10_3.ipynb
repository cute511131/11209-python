# %%
list1=["Tiffany",5,3,3,5]
list1
# Out:
# ['Tiffany', 5, 3, 3, 5]

# %%
list1[0]
# Out:
# 'Tiffany'

# %%
list1[4],list1[0]
# Out:
# (5, 'Tiffany')

# %%
dict1={'name':"tiffany",
      'dice1':5,
      'dice2':3,
      "dice3":3,
      'dice4':5}
dict1
# Out:
# {'name': 'tiffany', 'dice1': 5, 'dice2': 3, 'dice3': 3, 'dice4': 5}

# %%
dict1['name']
# Out:
# 'tiffany'
