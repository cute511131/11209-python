# %%
import tkinter as tk
from tkinter import ttk
from youbikeTreeView import YoubikeTreeView
from tkinter import messagebox
from threading import Timer
import datasource

class Window(tk.Tk):
    def __init__(self,**kwargs):
        super().__init__(**kwargs)
        #---------更新資料庫資料-----------------#
        try:
            datasource.updata_sqlite_data()
        except Exception:
            messagebox.showerror("錯誤",'網路不正常\n將關閉應用程式\n請稍後再試')
            self.destroy()           
         # 添加搜索框和搜索按钮
        search_frame = tk.Frame(self)
        tk.Label(search_frame, text="搜尋站點名稱：", font=("arial", 12)).pack(side='left', padx=5, pady=5)
        self.search_entry = tk.Entry(search_frame)
        self.search_entry.pack(side='left', padx=5, pady=5)
        search_button = tk.Button(search_frame, text="搜索", command=self.perform_search)
        search_button.pack(side='left', padx=5, pady=5)
        search_frame.pack()

        #---------建立介面------------------------
        #print(datasource.lastest_datetime_data())
        topFrame = tk.Frame(self,relief=tk.GROOVE,borderwidth=1)
        tk.Label(topFrame,text="台北市youbike及時資料",font=("arial", 20), bg="#333333", fg='#ffffff',padx=10,pady=10).pack(padx=20,pady=20)
        topFrame.pack(pady=30)

        bottomFrame = tk.Frame(self)
        #---------------建立treeView---------------
        self.youbikeTreeView = YoubikeTreeView(bottomFrame,show="headings",columns=('sna','mday','sarea','ar','tot','sbi','bemp'))
        self.youbikeTreeView.pack(side='left')
        vsb = ttk.Scrollbar(bottomFrame, orient="vertical", command=self.youbikeTreeView.yview)
        vsb.pack(side='left',fill='y')
        self.youbikeTreeView.configure(yscrollcommand=vsb.set)
        bottomFrame.pack(pady=30)
        print(datasource.search_sitename('三'))
        
    def perform_search(self):
            # 获取搜索关键字并执行搜索
            query = self.search_entry.get()
            search_result = datasource.search_sitename(query)
            
            # 更新 treeView 显示搜索结果
            self.youbikeTreeView.update_content(search_result)

        


def main():    
    def update_data(w:Window)->None:
        datasource.updata_sqlite_data()
        #-----------更新treeView資料---------------
        lastest_data = datasource.lastest_datetime_data()
        w.youbikeTreeView.update_content(lastest_data)

        window.after(3*60*1000,update_data,w) #每隔3分鐘
          

    window = Window()
    window.title('台北市youbike2.0')
    #window.geometry('600x300')
    window.resizable(width=False,height=False)
    update_data(window)          
    window.mainloop()

if __name__ == '__main__':
    main()
# Out:
# 下載成功
# create_table成功
# [('YouBike2.0_三張犁', '2023-11-01 16:55:09', '信義區', '光復南路455號前方', 40, 4, 36), ('YouBike2.0_三民公園', '2023-11-01 16:55:09', '松山區', '撫遠街298號對側公園', 22, 5, 16), ('YouBike2.0_三民公園(塔悠路)', '2023-11-01 16:55:09', '松山區', '塔悠路/撫遠街261巷(西側)', 20, 2, 18), ('YouBike2.0_三民國中(民權東路六段47巷)', '2023-11-01 16:55:09', '內湖區', '民權東路六段47巷6號對側', 13, 4, 9), ('
-11-01 16:55:09', '文山區', '忠順街一段木新路三段310巷口', 17, 9, 8), ('YouBike2.0_康寧路三段189巷93弄口', '2023-11-01 16:55:09', '內湖區', '康寧路三段189巷/康寧路三段189巷93弄', 14, 4, 10), ('YouBike2.0_康寧路三段54巷口', '2023-11-01 16:55:09', '內湖區', '康寧路三段54-5號西側', 15, 4, 11), ('YouBike2.0_康寧路三段99巷17弄口', '2023-11-01 16:55:09', '內湖區', '康寧路三段99巷19號對側', 15, 1, 14), ('YouBike2.0_忠孝東路三段217巷口', '2023-11-01 16:55:09', '大安區', '忠孝東路三段229-1號前', 34, 33, 1), ('YouBike2.0_成功路三段83號前', '2023-11-01 16:55:09', '內湖區', '成功路三段83號前', 11, 5, 6), ('YouBike2.0_承德路三段8巷口', '2023-11-01 16:55:09', '大同區', '承德路三段14號前', 16, 4, 12), ('YouBike2.0_捷運南京三民站(1號出口)', '2023-11-01 16:55:09', '松山區', '捷運南京三民站(1號出口)', 35, 7, 28), ('YouBike2.0_捷運南京三民站(2號出口)', '2023-11-01 16:55:09', '松山區', '南京東路五段156號(前)', 19, 4, 15), ('YouBike2.0_捷運南京三民站(3號出口)', '2023-11-01 16:55:09', '松山區', '捷運南京三民站(3號出口)', 33, 13, 20), ('YouBike2.0_捷運南京三民站(4號出口)', '2023-11-01 16:55:09', '松山區', '南京東路五段229號(前)', 13, 2, 11), ('YouBike2.0_捷運奇岩站(三合街)', '2023-11-01 16:55:09', '北投區', '三合街二段486號(旁)', 40, 28, 12), ('YouBike2.0_捷運萬芳醫院站(興隆路三段115巷)', '2023-11-01 16:55:09', '文山區', '興隆路三段115巷2號', 20, 0, 20), ('YouBike2.0_敬業三樂群三路口(西北側)', '2023-11-01 16:55:09', '中山區', '敬業三路/樂群三路口', 16, 3, 13), ('YouBike2.0_文化三杏林一路口', '2023-11-01 16:55:09', '北投區', '杏林一路3號(旁)', 17, 1, 16), ('YouBike2.0_文德三號公園(江南街71巷16弄)', '2023-11-01 16:55:09', '內湖區', '瑞光路271號東南側', 15, 1, 14), ('YouBike2.0_新湖三新湖二146巷口', '2023-11-01 16:55:09', '內湖區', '新湖三路122、124號對側', 15, 13, 2), ('YouBike2.0_新湖三民善街口', '2023-11-01 16:55:09', '內湖區', '新湖三路36號', 15, 14, 1), ('YouBike2.0_新湖三行忠路72巷口', '2023-11-01 16:55:09', '內湖區', '新湖三路/行忠路72巷', 15, 0, 15), ('YouBike2.0_新生南路三段52號前', '2023-11-01 16:55:09', '大安區', '新生南路三段52號', 17, 6, 11), ('YouBike2.0_新生南路三段66號前', '2023-11-01 16:55:09', '大安區', '新生南路三段66號東側', 16, 3, 12), ('YouBike2.0_新生南路三段82號前', '2023-11-0 ...
# 下載成功
# create_table成功
